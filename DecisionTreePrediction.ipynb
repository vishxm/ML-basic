# %% [markdown]
# <a href="https://colab.research.google.com/github/vishxm/ML-basic/blob/main/DecisionTreePrediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Prediction using Decision Trees
#
# ## Made by [Vishwas Modhera](https://www.linkedin.com/in/vishwas-modhera-a9b292162/)

# %% [markdown]
# Importing the necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# Importing the dataset

# %%
from sklearn import datasets

iris = datasets.load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)

# %% [markdown]
# Inspecting the dataset

# %%
plt.rcParams['figure.figsize'] = (5,4)
plt.rcParams['figure.dpi'] = 200
plt.plot(df)
plt.legend(df.columns)
plt.title("Iris dataset plot")
plt.show()

# %%
df.head(1)
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2

# %%
df['target'] = iris.target

# %%
df['target'] = df.target.map({0:'setosa', 1:'versicolor', 2:'virginica'})

# %%
sns.pairplot(data = df, hue='target')
plt.title("Pairplot of Iris dataset")
plt.show()

# %% [markdown]
# Let's implement Decision Tree Classifier for this dataset!

# %%
from sklearn.tree import DecisionTreeClassifier, export_graphviz

clf = DecisionTreeClassifier(criterion = 'entropy', max_depth = 3)

X = df.iloc[:, :4]
y = df.iloc[:, -1]



clf.fit(X, y)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=3, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %% [markdown]
# Let's visualise the trained classifier!

# %%
from sklearn import tree
from IPython.display import SVG, display
from graphviz import Source

# %%
labels = X.columns

graph = Source(tree.export_graphviz(clf, feature_names=labels, class_names=y.unique(), max_depth=3, filled=True))

display(SVG(graph.pipe(format='svg')))
